# %%
import re
from mongoengine import connect, disconnect
from pycoshark.mongomodels import Project, VCSSystem, Commit, FileAction, Hunk, Refactoring, IssueSystem, Issue, IssueComment, MailingList, Message,PullRequestSystem
from pycoshark.utils import create_mongodb_uri_string


# You may have to update this dict to match your DB credentials
disconnect()
credentials = {'db_user': '',
               'db_password': '',
               'db_hostname': 'localhost',
               'db_port': 27017,
               'db_authentication_database': '',
               'db_ssl_enabled': False}

uri = create_mongodb_uri_string(**credentials)

connect('smartshark_2_1', host=uri, alias='default')
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True, read_preference=Primary())

# %%
commit_id = []
project = Project.objects(name='tika').get()

for fa in FileAction.objects.all():
    if fa.induces != [] :
        for i in fa.induces:
            if i['szz_type'] == 'inducing':
                commit = Commit.objects(id=fa.commit_id).get()
                vcs_system = VCSSystem.objects(id=commit.vcs_system_id, project_id=project.id)
                if vcs_system and commit.id not in commit_id:
                    commit_id.append(commit.id)
                    print(commit.id)
# Out:
# 5b4854813463875e5e15cfb8
# 5b4854813463875e6115cfb1
# 5b4854813463875e6215cfb5
# 5b4854813463875e6315cfa1
# 5b4854813463875e6515cf9b
# 5b4854813463875e6615cfce
# 5b4854813463875e6815cfa4
# 5b4854813463875e6915cfad
# 5b4854813463875e6a15cf9b
# 5b4854813463875e6a15cfac
# 5b4854823463875e5d15d013
# 5b4854823463875e5f15cfed
# 5b4854823463875e6015cfd6
# 5b4854823463875e6015cfea
# 5b4854823463875e6015cff6
# 5b4854823463875e6115cfc5
# 5b4854823463875e6215cfe3
# 5b4854823463875e6315cfe0
# 5b4854823463875e6515cfc8
# 5b4854823463875e6515cfdd
# 5b4854823463875e6515cfe3
# 5b4854823463875e6615cffe
# 5b4854823463875e6715cfc3
# 5b4854813463875e6815cfb0
# 5b4854823463875e6a15cfb8
# 5b4854823463875e6a15cfc6
# 5b4854823463875e6b15cfb4
# 5b4854823463875e6b15cfcc
# 5b4854823463875e6c15cfdb
# 5b4854843463875e5d15d01b
# 5b4854843463875e5e15d002
# 5b4854843463875e6015d017
# 5b4854843463875e6015d01d
# 5b4854843463875e6215cff1
# 5b4854843463875e6315d02e
# 5b4854843463875e6415d003
# 5b4854843463875e6515cfff
# 5b4854843463875e6615d021
# 5b4854843463875e6615d036
# 5b4854843463875e6715cfdd
# 5b4854843463875e6b15cffa
# 5b4854853463875e5d15d03e
# 5b4854853463875e5e15d05c
# 5b4854843463875e6115cfe9
# 5b4854853463875e6115d026
# 5b4854853463875e6215d025
# 5b4854853463875e6315d069
# 5b4854853463875e6615d07c
# 5b4854853463875e6915d02c
# 5b4854853463875e6a15cffc
# 5b4854853463875e6c15d066
# 5b4854863463875e5e15d080
# 5b4854863463875e6315d095
# 5b4854863463875e6615d097
# 5b4854863463875e6715d031
# 5b4854863463875e6915d081
# 5b4854863463875e6c15d08d
# 5b4854893463875e5d15d07b
# 5b4854893463875e6415d08e
# 5b4854893463875e6515d157
# 5b48548b3463875e6615d0ad
# 5b48548b3463875e6815d044
# 5b48548b3463875e6915d09c
# 5b48548b3463875e6a15d081
# 5b4854c23463875e5e15e95f
# 5b4854c23463875e6015eadc
# 5b4854c23463875e6315e6c3
# 5b4854c23463875e6815e8b1
# 5b4854c23463875e6815e929
# 5b4854c33463875e6015eb97
# 5b4854c33463875e6015eba9
# 5b4854c33463875e6315e806
# 5b4854c33463875e6415eb02
# 5b4854c33463875e6615e990
# 5b4854c33463875e6715ece1
# 5b4854c33463875e6915e858
# 5b4854c33463875e6c15efb1
# 5b4854c43463875e5d15ee21
# 5b4854c43463875e5e15eab5
# 5b4854c43463875e6015ec31
# 5b4854c43463875e6215e761
# 5b4854c43463875e6215e781
# 5b4854c43463875e6515ecbd
# 5b4854c43463875e6615ea5a
# 5b4854c43463875e6715ed4a
# 5b4854c43463875e6715eda4
# 5b4854c43463875e6715edd5
# 5b4854c43463875e6815eaae
# 5b4854c43463875e6815eb10
# 5b4854c43463875e6915e8c8
# 5b4854c43463875e6a15f129
# 5b4854c53463875e6415ec92
# 5b4854c53463875e6615eaeb
# 5b4854c53463875e6715ee26
# 5b4854c43463875e6915e955
# 5b4854c73463875e6415ece1
# 5b4854bf3463875e6b15e65d
# 5b4854c83463875e5d15ef15
# 5b4854ca3463875e5d15ef44
# 5b4854ce3463875e6215e90f
# 5b4854d03463875e6915ea9e
# 5b4854d23463875e6815ecef
# 5b4854e33463875e6215ea9c
# 5b4854e53463875e5e15f075
# 5b4854ea3463875e6715f094
# 5b4854ed3463875e6615ee3f
# 5b4854f13463875e6715f12e
# 5b4854f23463875e6715f137
# 5b4854f23463875e6015f25a
# 5b4854f43463875e6215ec1c
# 5b4854f53463875e6415f15e
# 5b4854f63463875e6615eef9
# 5b4854f63463875e5d15f338
# 5b4854f83463875e6215ec8d
# 5b4854f73463875e6515f1ec
# 5b4854f83463875e6715f1c7
# 5b4854f83463875e6915edb4
# 5b4854f83463875e6215ec9a
# 5b4854fa3463875e6715f325
# 5b4854f53463875e6015f300
# 5b4854fb3463875e6915eff1
# 5b4854fd3463875e6515f51f
# 5b4854fe3463875e6115f970
# 5b4854fe3463875e6215f0c7
# 5b4854ff3463875e5e15f621
# 5b4855003463875e5e15f6a7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 10
#       8 commit = Commit.objects(id=fa.commit_id).get()
#       9 vcs_system = VCSSystem.objects(id=commit.vcs_system_id, project_id=project.id)
# ---> 10 if vcs_system and commit.id not in commit_id:
#      11     commit_id.append(commit.id)
#      12     print(commit.id)
#
# File ~/smart shark/usage-examples/venv/lib/python3.8/site-packages/mongoengine/queryset/base.py:216, in BaseQuerySet.__bool__(self)
#     214 def __bool__(self):
#     215     """Avoid to open all records in an if stmt in Py3."""
# --> 216     return self._has_data()
#
# File ~/smart shark/usage-examples/venv/lib/python3.8/site-packages/mongoengine/queryset/base.py:212, in BaseQuerySet._has_data(self)
#     210 """Return True if cursor has any data."""
#     211 queryset = self.order_by()
# --> 212 return False if queryset.first() is None else True
#
# File ~/smart shark/usage-examples/venv/lib/python3.8/site-packages/mongoengine/queryset/base.py:290, in BaseQuerySet.first(self)
#     288 queryset = self.clone()
#     289 try:
# --> 290     result = queryset[0]
#     291 except IndexError:
#     292     result = None
#
# File ~/smart shark/usage-examples/venv/lib/python3.8/site-packages/mongoengine/queryset/base.py:200, in BaseQuerySet.__getitem__(self, key)
#     196     if queryset._as_pymongo:
#     197         return queryset._cursor[key]
#     199     return queryset._document._from_son(
# --> 200         queryset._cursor[key],
#     201         _auto_dereference=self._auto_dereference,
#     202     )
#     204 raise TypeError("Provide a slice or an integer index")
#
# File ~/smart shark/usage-examples/venv/lib/python3.8/site-packages/pymongo/cursor.py:692, in Cursor.__getitem__(self, index)
#     690 clone.limit(-1)  # use a hard limit
#     691 clone.__query_flags &= ~CursorType.TAILABLE_AWAIT  # PYTHON-1371
# --> 692 for doc in clone:
#     693     return doc
#     694 raise IndexError("no such item for Cursor instance")
#
# File ~/smart shark/usage-examples/venv/lib/python3.8/site-packages/pymongo/cursor.py:1238, in Cursor.next(self)
#    1236 if self.__empty:
#    1237     raise StopIteration
# -> 1238 if len(self.__data) or self._refresh():
#    1239     if self.__manipulate:
#    1240         _db = self.__collection.database
#
# File ~/smart shark/usage-examples/venv/lib/python3.8/site-packages/pymongo/cursor.py:1155, in Cursor._refresh(self)
#    1134         warnings.warn("using a min/max query operator without "
#    1135                       "specifying a Cursor.hint is deprecated. A "
#    1136                       "hint will be required when using min/max in "
#    1137                       "PyMongo 4.0",
#    1138                       DeprecationWarning, stacklevel=3)
#    1139     q = self._query_class(self.__query_flags,
#    1140                           self.__collection.database.name,
#    1141                           self.__collection.name,
#    (...)
#    1153                           self.__allow_disk_use,
#    1154                           self.__exhaust)
# -> 1155     self.__send_message(q)
#    1156 elif self.__id:  # Get More
#    1157     if self.__limit:
#
# File ~/smart shark/usage-examples/venv/lib/python3.8/site-packages/pymongo/cursor.py:1044, in Cursor.__send_message(self, operation)
#    1040     raise InvalidOperation(
#    1041         "exhaust cursors do not support auto encryption")
#    1043 try:
# -> 1044     response = client._run_operation(
#    1045         operation, self._unpack_response, address=self.__address)
#    1046 except OperationFailure as exc:
#    1047     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1048         # Don't send killCursors because the cursor is already closed.
#
# File ~/smart shark/usage-examples/venv/lib/python3.8/site-packages/pymongo/mongo_client.py:1424, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1419 def _cmd(session, server, sock_info, secondary_ok):
#    1420     return server.run_operation(
#    1421         sock_info, operation, secondary_ok, self._event_listeners,
#    1422         unpack_res)
# -> 1424 return self._retryable_read(
#    1425     _cmd, operation.read_preference, operation.session,
#    1426     address=address, retryable=isinstance(operation, message._Query))
#
# File ~/smart shark/usage-examples/venv/lib/python3.8/site-packages/pymongo/mongo_client.py:1525, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1521         if retrying and not retryable:
#    1522             # A retry is not possible because this server does
#    1523             # not support retryable reads, raise the last error.
#    1524             raise last_error
# -> 1525         return func(session, server, sock_info, secondary_ok)
#    1526 except ServerSelectionTimeoutError:
#    1527     if retrying:
#    1528         # The application may think the write was never attempted
#    1529         # if we raise ServerSelectionTimeoutError on the retry
#    1530         # attempt. Raise the original exception instead.
#
# File ~/smart shark/usage-examples/venv/lib/python3.8/site-packages/pymongo/mongo_client.py:1420, in MongoClient._run_operation.<locals>._cmd(session, server, sock_info, secondary_ok)
#    1419 def _cmd(session, server, sock_info, secondary_ok):
# -> 1420     return server.run_operation(
#    1421         sock_info, operation, secondary_ok, self._event_listeners,
#    1422         unpack_res)
#
# File ~/smart shark/usage-examples/venv/lib/python3.8/site-packages/pymongo/server.py:114, in Server.run_operation(self, sock_info, operation, set_secondary_okay, listeners, unpack_res)
#     112 else:
#     113     sock_info.send_message(data, max_doc_size)
# --> 114     reply = sock_info.receive_message(request_id)
#     116 # Unpack and check for command errors.
#     117 if use_cmd:
#
# File ~/smart shark/usage-examples/venv/lib/python3.8/site-packages/pymongo/pool.py:753, in SocketInfo.receive_message(self, request_id)
#     751     return receive_message(self, request_id, self.max_message_size)
#     752 except BaseException as error:
# --> 753     self._raise_connection_failure(error)
#
# File ~/smart shark/usage-examples/venv/lib/python3.8/site-packages/pymongo/pool.py:751, in SocketInfo.receive_message(self, request_id)
#     746 """Receive a raw BSON message or raise ConnectionFailure.
#     747
#     748 If any exception is raised, the socket is closed.
#     749 """
#     750 try:
# --> 751     return receive_message(self, request_id, self.max_message_size)
#     752 except BaseException as error:
#     753     self._raise_connection_failure(error)
#
# File ~/smart shark/usage-examples/venv/lib/python3.8/site-packages/pymongo/network.py:200, in receive_message(sock_info, request_id, max_message_size)
#     197     deadline = None
#     198 # Ignore the response's request id.
#     199 length, _, response_to, op_code = _UNPACK_HEADER(
# --> 200     _receive_data_on_socket(sock_info, 16, deadline))
#     201 # No request_id for exhaust cursor "getMore".
#     202 if request_id is not None:
#
# File ~/smart shark/usage-examples/venv/lib/python3.8/site-packages/pymongo/network.py:291, in _receive_data_on_socket(sock_info, length, deadline)
#     289 try:
#     290     wait_for_read(sock_info, deadline)
# --> 291     chunk_length = sock_info.sock.recv_into(mv[bytes_read:])
#     292 except (IOError, OSError) as exc:
#     293     if _errno_from_exception(exc) == errno.EINTR:
#
# KeyboardInterrupt:

# %%
from pycoshark.mongomodels import PullRequest, PullRequestCommit

my_dict = []

print("Number of total bug inducing commits in tika: " + str(len(commit_id)))
pull_request_system = PullRequestSystem.objects(project_id=project.id).get()
pr = PullRequest.objects(pull_request_system_id=pull_request_system.id)
print("Number of pull-request in the project: " + str(pr.count()))

for item in pr:
    pr_commit = PullRequestCommit.objects(pull_request_id=item.id)
    for value in pr_commit:
        if value.commit_id in commit_id:
            
            for key in my_dict:
                if key["pull_request"] == item.id:
                    key["commit_count"] += 1
            else:
                dict = {"pull_request":item.id,
                       "commit_count": 1,
                       "time_difference": item.updated_at - item.created_at}
                my_dict.append(dict)
                                             

print(len(my_dict))
# Out:
# Number of total bug inducing commits in tika: 919
# Number of pull-request in the project: 394
# 59

# %%
from matplotlib import pyplot as plt
import matplotlib.dates as mdates
import numpy as np

x = []
y = []
for item in my_dict:
    x.append(item["time_difference"].days)
    y.append(item["commit_count"])

plt.scatter(x,y)    
plt.gcf().autofmt_xdate()
plt.xlabel("Review Time in days")
plt.ylabel("Count of Bug-inducing commits")
plt.show()

# %%
vcs_system = VCSSystem.objects(project_id=project.id).get()


print('VCS System:', vcs_system.url)

# We can now fetch the commits and analyze them
num_commits = Commit.objects(vcs_system_id=vcs_system.id).count()

print('Number of commits:', num_commits)

count_bugfix = 0
count_linked_issue = 0
count_hunks = 0
count_refactorings_refdiff = 0
count_refactorings_refactoringminer = 0

# Only limits the fields we are reading to the required fields. This is important for the performance.
for commit in Commit.objects(vcs_system_id=vcs_system.id).only('labels', 'linked_issue_ids'):
    if commit.labels is not None and 'validated_bugfix' in commit.labels and commit.labels['validated_bugfix']==True:
        count_bugfix += 1
    if commit.linked_issue_ids is not None and len(commit.linked_issue_ids)>0:
        count_linked_issue += 1
        
    # File actions group all changed hunks in a commit of the same file
    for fa in FileAction.objects(commit_id=commit.id):
        count_hunks += Hunk.objects(file_action_id=fa.id).count()
        
    count_refactorings_refdiff += Refactoring.objects(commit_id=commit.id, detection_tool='"refDiff"').count()
    count_refactorings_refactoringminer += Refactoring.objects(commit_id=commit.id, detection_tool='rMiner').count()

        
print('Number of bug fixing commits:', count_bugfix)
print('Number of commits that link to a Jira issue:', count_linked_issue)
print('Number of hunks for all commits:', count_hunks)
print('Number of refactorings detected by refDiff:', count_refactorings_refdiff)
print('Number of refactorings detected by RefactoringMiner:', count_refactorings_refactoringminer)
# Out:
# VCS System: https://github.com/apache/tika.git
# Number of commits: 4933
# Number of bug fixing commits: 670
# Number of commits that link to a Jira issue: 3504
# Number of hunks for all commits: 82254
# Number of refactorings detected by refDiff: 0
# Number of refactorings detected by RefactoringMiner: 3077
